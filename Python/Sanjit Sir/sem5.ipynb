# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('Studentdata.csv')
#print(df)

plt.scatter(df['Study Hour'], df['CGPA'], marker='o')

plt.xlabel("Study Hours")
plt.ylabel("CGPA")
plt.title("Study hours vs CGPA")
plt.grid("True")
plt.show()
