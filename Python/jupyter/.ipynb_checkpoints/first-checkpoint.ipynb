# %%
print("Hello World")
print("We love Python")
# Out:
# Hello World
# We love Python

# %%
import matplotlib as plt
x=[1,34,6,89,76]
y=[4,76,1,36,87]
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 x=[1,34,6,89,76]
#       3 y=[4,76,1,36,87]
# ----> 4 plt.plot(x,y)
#       5 plt.show()
#
# File /usr/lib/python3/dist-packages/matplotlib/_api/__init__.py:224, in caching_module_getattr.<locals>.__getattr__(name)
#     222 if name in props:
#     223     return props[name].__get__(instance)
# --> 224 raise AttributeError(
#     225     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'
