# %%
with open("new1.txt","w") as n1:
    data = n1.write("Hello")

# %%
c = open('new1.txt')

print(c.read())
# Out:
# Hello world

# %%
with open("new2.txt","r") as f:
    data = f.readlines()
    print(data)
# Out:
# ['a\n', 'b\n', 'c\n', 'd\n', 'e\n', 'f\n', 'h']
