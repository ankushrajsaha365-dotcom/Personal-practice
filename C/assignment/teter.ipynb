# %%
n = int(input("Enter a number:"))

if n%2 != 0:
    print("Weird")
else:
    if n>=2 and n<=5:
        print("Not Weird")
    elif n>=6 and n<=20 :
        print("Weird")
    elif n>=20:
        print("Not Weird")
# Out:
# Not Weird

# %%
n=5
x
# Out:
# 1
# 2
# 3
# 4
