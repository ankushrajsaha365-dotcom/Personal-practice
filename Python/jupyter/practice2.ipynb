# %% [markdown]
# Write a program that accepts a sentence and calculate the number of upper-case
#
# letters and lower-case letters.
#
# Input Format: The first line of the input contains a statement.
#
# Output Format: Print the number of upper case and lower case respectively.
#
# Example: Input: Hello world!
# Output: 1 9

# %%
str = input("Enter the statement:")
upper,lower=0,0
for i in str:
    if 97<=ord(i)<=122 :
        lower+=1
    if 65<=ord(i)<=90:
        upper+=1

print(f"upper case :{upper} \nlower case :{lower}")
# Out:
# upper case :1
# lower case :9

# %% [markdown]
# Write a program to show all the common words between two strings.

# %%
A = input("Statement 'A':")
B = input("Statement 'B':")

for i in A.split():
    for j in B.split():
        if i == j:
            print(i)
# Out:
# there

# %%
A ="Ajkf agba ksjg"
print(A.split())
# Out:
# ['Ajkf', 'agba', 'ksjg']

# %% [markdown]
# Write a program that accepts sequence of lines as input and prints all the
#
# lines after making all characters in the sentence capitalized.
#
# Input Format: The first line of the input contains a number n which represents
#
# the number of lines. From the second line there are sentences that are to be
#
# converted. Each statement comes in a new line
#
# Output Format: Display the sentence with all the words in capital letter.
#
# Example:
#
# Input: 1
#
# Hello world Practice makes perfect
#
# Output: HELLO WORLD PRACTICE MAKES PERFECT

# %%
str = input("Enter the statement:")
print(str.upper())
# Out:
# HELLO WORLD PRACTICE MAKES PERFECT

# %% [markdown]
# Write a program that accepts a comma-separated sequence of words as input and prints
#
# the words in a comma-separated sequence after sorting them alphabetically.
#
# Input Format: The first line of input contains words separated by the comma.
#
# Output Format: Print the sorted words separated by the comma.
#
# Example:
#
# Input: without, hello, bag, world
#
# Output: bag, hello, without, world

# %%
l = input("Enter the comma separated list:")

l1 = l.split(",")
l1.sort()

print(",".join(l1))
# Out:
# a,b,f,v,x

# %% [markdown]
# If we have some email addresses in the "username@companyname.com" format,
#
# please write program to print the company name of a given email address. Both
#
# usernames and company names are composed of letters only.
#
# Input Format: The first line of the input contains an email address.
#
# Output Format: Print the company name in single line.
#
# Example;
#
# Input: john@google.com
#
# Output: google

# %%
id = input("Enter the email address:")
com = id.split("@." + ".")
print(com)
# Out:
# ['john@google.com']

# %%
email = input().strip()

# Split at '@' → ["username", "company.com"]
_, domain = email.split("@")

# Split domain at '.' → ["company", "com"]
company, _ = domain.split(".")

print(company)
# Out:
# gmail

# %%
email = input("Enter your email address:")
e = email.strip()
_, domain = e.split("@")
com,_= domain.split(".")
print(com)
# Out:
# yahoo
