# %%
def mean(l):
    sum = 0
    for j in l:
        sum+=j
        mean = sum/n
    return mean

def sum(l):
    sum = 0
    for j in l:
        sum+=j
    return sum

def sqsum(l):
    sq_sum = 0
    for j in l:
        sq_sum+=(j**2)
    return sq_sum

def mulsum(l1,l2):
    mul_sum = 0
    for i in range(len(l1)):
        mul_sum+=l1[i]*l2[i]
    return mul_sum

X = []
Y = []
n = int(input("Enter no of inputs:"))

for i in range(n):
    x_value = int(input("Enter value:"))
    X.append(x_value)
print("X-axis:",X)

for i in range(n):
    y_value = int(input("Enter value:"))
    Y.append(y_value)
print("Y-axis:",Y)

# print(sum(X))
# print(sqsum(X))
# print(mulsum(X,Y))

#Reg coeff of x on y (b_xy)

b_xy = ((n*mulsum(X,Y))-(sum(X)*sum(Y)))/((n*sqsum(Y))-((sum(X))**2))

print(b_xy)
# Out:
# X-axis: [1, 2, 3, 4, 5]
# Y-axis: [6, 7, 8, 9, 10]
# 0.03508771929824561
