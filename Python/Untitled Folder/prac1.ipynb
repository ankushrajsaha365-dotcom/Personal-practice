# %%
print("Hello ,Python adventurer!")
name  = input("Enter your name:")
age = int(input("Enter your age:"))

print(f"Welcome {name} , guess you are {age} years old")
# Out:
# Hello ,Python adventurer!
# Welcome Raj , guess you are 20 years old

# %% [markdown]
# level **

# %%
#even or odd

num = int(input("Enter a number"))
if num%2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
#Largest number

a = int(input("Enter a number a: "))
b = int(input("Enter a number b: "))
c = int(input("Enter a number c: "))

if a >= b and a >= c:
    print("a is the largest number")
elif b >= a and b >= c:
    print("b is the largest number")
else:
    print("c is the largest number")
# Out:
# b is the largest number

# %%
# Multiplication table

num = int(input("Enter a number:"))

for i in range(1,11):
    m = num*i
    print(f"{num} X {i} = {m}")
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 3 X 10 = 30

# %%
# Sum of n numbers

n = int(input("Enter a number:"))
sum=0

for i in range(n+1):
    sum+=i

print(f"sum of {n} numbers is {sum}")
# Out:
# sum of 10 numbers is 55

# %%
# Guess the Number (Mini Game) 🎯

secret = 7

guess = int(input("Enter a number"))

if guess == secret :
    print("Congrats you guessed right")

else:
    print("Sorry ,try again")
# Out:
# Congrats you guessed right

# %%
# Guess the Number (Mini Game) 🎯 modded

secret = 7
guess = int(input("Enter a number"))

if guess == secret :
    print("Congrats you guessed right")

elif guess in range(4,10):
    print("You are close...\nWanna try again?")

else:
    print("Sorry ,try again")
# Out:
# You are close...
# Wanna try again?
